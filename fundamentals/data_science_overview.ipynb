# %% [markdown]
# # Data Science
# ---
# Note that all the text images came from the book 'Data Science For Business'
# [Book Link](https://www.amazon.com/Data-Science-Business-Data-Analytic-Thinking-ebook/dp/B00E6EQ3X4)
#
# ## Index
# ---
# 1. Data Science Overview
# 2. Data Mining Alogrithms
# 3. Supervised vs. Unsupervised Methods
# 4. Data Mining Process & Techniques

# %% [markdown]
# ## 1. Data Science Overview
# ---

# %% [markdown]
# <img src='data/images/img163.PNG'>

# %% [markdown]
# <img src='data/images/img164.PNG'>

# %% [markdown]
# <img src='data/images/img165.PNG'>

# %% [markdown]
# <img src='data/images/img166.PNG'>

# %% [markdown]
# <img src='data/images/img167.PNG'>

# %% [markdown]
# ## Fundamental Concepts of Data Science

# %% [markdown]
# <img src='data/images/img168.PNG'>

# %% [markdown]
# <img src='data/images/img169.PNG'>

# %% [markdown]
# <img src='data/images/img170.PNG'>

# %% [markdown]
# <img src='data/images/img171.PNG'>

# %% [markdown]
# ## 2. Data Mining Alogrithms
# ---

# %% [markdown]
# <img src='data/images/img172.PNG'>

# %% [markdown]
# ### Classification
# **Used to predict whether something will happen.**

# %% [markdown]
# <img src='data/images/img173.PNG'>

# %% [markdown]
# <img src='data/images/img174.PNG'>

# %% [markdown]
# ### Regression
# **Used to predict how much something will happen.**

# %% [markdown]
# <img src='data/images/img175.PNG'>

# %% [markdown]
# ### Similarity Matching

# %% [markdown]
# <img src='data/images/img176.PNG'>

# %% [markdown]
# ### Clustering

# %% [markdown]
# <img src='data/images/img177.PNG'>

# %% [markdown]
# ### Co-Occurence Grouping (aka: market-based analysis)

# %% [markdown]
# <img src='data/images/img178.PNG'>

# %% [markdown]
# ### Profiling

# %% [markdown]
# <img src='data/images/img179.PNG'>

# %% [markdown]
# ### Link Prediction

# %% [markdown]
# <img src='data/images/img180.PNG'>

# %% [markdown]
# ### Data Reduction

# %% [markdown]
# <img src='data/images/img181.PNG'>

# %% [markdown]
# <img src='data/images/img182.PNG'>

# %% [markdown]
# ### Causal Modeling

# %% [markdown]
# <img src='data/images/img183.PNG'>

# %% [markdown]
# ## 3. Supervised vs. Unsupervised Methods

# %% [markdown]
# <img src='data/images/img184.PNG'>

# %% [markdown]
# <img src='data/images/img185.PNG'>

# %% [markdown]
# <img src='data/images/img186.PNG'>

# %% [markdown]
# <img src='data/images/img187.PNG'>

# %% [markdown]
# <img src='data/images/img188.PNG'>

# %%
<img src='data/images/img189.PNG'>

# %% [markdown]
# ## 4. Data Mining Process & Techniques
# ---

# %% [markdown]
# <img src='data/images/img190.PNG'>

# %% [markdown]
# <img src='data/images/img191.PNG'>

# %% [markdown]
# **The above diagram shows the typical data analysis model, the steps are:**
#
# 1. Defining The Objective (Business Understanding/Requirements)
# 2. Data Gathering/Acquisition
# 3. Data Processing (Preparation/Cleaning)
# 4. Data Exploration (find & understand patterns, retrieve useful insight, create hypothesis, ect.)
# 5. Building a Model and Evaluating the Model (Using Machine Learning)
# 6. Deployment of Model

# %% [markdown]
# <img src='data/images/img194.PNG'>

# %% [markdown]
# <img src='data/images/img195.PNG'>

# %% [markdown]
# <img src='data/images/img196.PNG'>

# %% [markdown]
# <img src='data/images/img197.PNG'>

# %% [markdown]
# <img src='data/images/img198.PNG'>

# %% [markdown]
# <img src='data/images/img199.PNG'>

# %% [markdown]
# <img src='data/images/img200.PNG'>

# %% [markdown]
# <img src='data/images/img201.PNG'>

# %% [markdown]
# <img src='data/images/img202.PNG'>

# %% [markdown]
# # TODO
